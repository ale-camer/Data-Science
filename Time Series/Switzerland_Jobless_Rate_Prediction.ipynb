# %% [markdown]
# <a href="https://colab.research.google.com/github/ale-camer/Data-Science/blob/Finance/Switzerland_Jobless_Rate_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests # packages
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data = requests.get("https://data.snb.ch/api/cube/amarbma/data/csv/en").text # data
data[:100]
# Out:
# '"CubeId";"amarbma"\r\n"PublishingDate";"2022-04-21 09:00"\r\n\r\n"Date";"D0";"Value"\r\n"1948-01";"K";\r\n"194'

# %%
# PREPROCESSING

data = str(data).splitlines() # convert each line an element of a list
data = pd.Series(data).str.split(';', expand=True) # separate each element by semicolon
data = data.iloc[5:,:].rename(columns = {0:'date',1:'category_code',2:'value'}) # delete unnecesary data and rename columns
for col in data.columns: # clean data
    data[col] = data[col].str.replace('"','').replace('', 0)
data['value'] = pd.to_numeric(data['value']) # format data
data = data[data['category_code'] == 'T1'] # keep only total jobless rate data
data.drop('category_code',axis=1,inplace=True) # drop category column
data.set_index('date',inplace=True) # set date as index
data.index = pd.to_datetime(data.index)
data.head()
# Out:
#                value
# date
# 1948-01-01  0.219472
# 1948-02-01  0.282811
# 1948-03-01  0.050011
# 1948-04-01  0.043687
# 1948-05-01  0.040072

# %%
date = '2015-12-01'
train, test = data[data.index <= date], data[data.index > date] # train and test sets
window_size, cycle = 10, 12
x_train, x_test, y_train, y_test = pd.concat([train['value'].shift(w, fill_value=0) for w in range(1, window_size+1)], axis=1, keys=[f"value_{w}" for w in range(1, window_size+1)]), \
    pd.concat([test['value'].shift(w, fill_value=0) for w in range(1, window_size+1)], axis=1, keys=[f"value_{w}" for w in range(1, window_size+1)]), \
    train['value'], test['value']
x_train, x_test = x_train.values.reshape((x_train.shape[0], 1, window_size)), x_test.values.reshape((x_test.shape[0], 1, window_size))
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((816, 1, 10), (75, 1, 10), (816,), (75,))

# %%
model = tf.keras.models.Sequential([ # model
  tf.keras.layers.InputLayer(input_shape=[1, window_size]),
  tf.keras.layers.LSTM(cycle),
  tf.keras.layers.Dense(1),
])
model.compile(loss="mean_squared_error", optimizer="adam", metrics="mean_squared_error")
history = model.fit(x_train, y_train, epochs=100, batch_size=1, verbose=True)
preds = model.predict(x_test) # prediction
rsme, corr = np.sqrt(np.mean((preds.flatten() - y_test)**2)), np.corrcoef(preds.flatten(), y_test)[0][1] # evaluation
# Out:
# Epoch 1/100
# 816/816 [==============================] - 4s 3ms/step - loss: 0.6690 - mean_squared_error: 0.6690
# Epoch 2/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0657 - mean_squared_error: 0.0657
# Epoch 3/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0461 - mean_squared_error: 0.0461
# Epoch 4/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0393 - mean_squared_error: 0.0393
# Epoch 5/100
# 816/816 [==============================] - 3s 3ms/step - loss: 0.0308 - mean_squared_error: 0.0308
# Epoch 6/100
# 816/816 [==============================] - 3s 4ms/step - loss: 0.0284 - mean_squared_error: 0.0284
# Epoch 7/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0269 - mean_squared_error: 0.0269
# Epoch 8/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0236 - mean_squared_error: 0.0236
# Epoch 9/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0227 - mean_squared_error: 0.0227
# Epoch 10/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0218 - mean_squared_error: 0.0218
# Epoch 11/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0217 - mean_squared_error: 0.0217
# Epoch 12/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0167 - mean_squared_error: 0.0167
# Epoch 13/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0202 - mean_squared_error: 0.0202
# Epoch 14/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0162 - mean_squared_error: 0.0162
# Epoch 15/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 16/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0174 - mean_squared_error: 0.0174
# Epoch 17/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0166 - mean_squared_error: 0.0166
# Epoch 18/100
# 816/816 [==============================] - 3s 3ms/step - loss: 0.0187 - mean_squared_error: 0.0187
# Epoch 19/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 20/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0148 - mean_squared_error: 0.0148
# Epoch 21/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0149 - mean_squared_error: 0.0149
# Epoch 22/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0160 - mean_squared_error: 0.0160
# Epoch 23/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0179 - mean_squared_error: 0.0179
# Epoch 24/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 25/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 26/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0168 - mean_squared_error: 0.0168
# Epoch 27/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 28/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0132 - mean_squared_error: 0.0132
# Epoch 29/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 30/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 31/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0151 - mean_squared_error: 0.0151
# Epoch 32/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 33/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 34/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0132 - mean_squared_error: 0.0132
# Epoch 35/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 36/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 37/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 38/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0140 - mean_squared_error: 0.0140
# Epoch 39/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0120 - mean_squared_error: 0.0120
# Epoch 40/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0130 - mean_squared_error: 0.0130
# Epoch 41/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0138 - mean_squared_error: 0.0138
# Epoch 42/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0130 - mean_squared_error: 0.0130
# Epoch 43/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 44/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 45/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0168 - mean_squared_error: 0.0168
# Epoch 46/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0135 - mean_squared_error: 0.0135
# Epoch 47/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0142 - mean_squared_error: 0.0142
# Epoch 48/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0130 - mean_squared_error: 0.0130
# Epoch 49/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 50/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0138 - mean_squared_error: 0.0138
# Epoch 51/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 52/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 53/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0134 - mean_squared_error: 0.0134
# Epoch 54/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 55/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 56/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 57/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 58/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 59/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0119 - mean_squared_error: 0.0119
# Epoch 60/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0111 - mean_squared_error: 0.0111
# Epoch 61/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0126 - mean_squared_error: 0.0126
# Epoch 62/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0127 - mean_squared_error: 0.0127
# Epoch 63/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 64/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 65/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0128 - mean_squared_error: 0.0128
# Epoch 66/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 67/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 68/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 69/100
# 816/816 [==============================] - 3s 3ms/step - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 70/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 71/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 72/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 73/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 74/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0108 - mean_squared_error: 0.0108
# Epoch 75/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0111 - mean_squared_error: 0.0111
# Epoch 76/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 77/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0116 - mean_squared_error: 0.0116
# Epoch 78/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 79/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 80/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 81/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0122 - mean_squared_error: 0.0122
# Epoch 82/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0118 - mean_squared_error: 0.0118
# Epoch 83/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 84/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0109 - mean_squared_error: 0.0109
# Epoch 85/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0097 - mean_squared_error: 0.0097
# Epoch 86/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0124 - mean_squared_error: 0.0124
# Epoch 87/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0106 - mean_squared_error: 0.0106
# Epoch 88/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 89/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 90/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0105 - mean_squared_error: 0.0105
# Epoch 91/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0108 - mean_squared_error: 0.0108
# Epoch 92/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 93/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 94/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 95/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 96/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0099 - mean_squared_error: 0.0099
# Epoch 97/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0109 - mean_squared_error: 0.0109
# Epoch 98/100
# 816/816 [==============================] - 2s 2ms/step - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 99/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 100/100
# 816/816 [==============================] - 2s 3ms/step - loss: 0.0108 - mean_squared_error: 0.0108

# %%
plt.figure(figsize=(30,10)) # plot
plt.plot(data.index, data['value'], label="Total jobless rate")
plt.plot(test.index[window_size:], preds[window_size:], label="Prediction")
plt.xlabel("Months",fontsize=20)
plt.ylabel("Jobless Rate (%)",fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.suptitle("Switzerland Jobless Rate Prediction",fontsize=30)
plt.title(f"RSME: {round(rsme,2)}. Correlation coefficient: {round(corr*100,2)}%",fontsize=20)
plt.legend(fontsize=20)
plt.show()
